# %% [markdown]
# ## **1. Import Librairies:**

# %%
import pandas as pd
import requests

# %% [markdown]
# ## **2. Load Datasets:**

# %%
timetables = pd.read_csv('timetables.csv', sep="\t")
routes = pd.read_csv('data_sncf/routes.csv', sep=",")

# %% [markdown]
# ### **a. Timetable:**

# %%
timetables
# Out:
#                      trip_id  \
# 0      OCESN003100F140147152
# 1      OCESN003190F040047309
# 2      OCESN003198F030037315
# 3      OCESN003300F030037323
# 4      OCESN003313F380387526
# ...                      ...
# 1570  OCESN895822F0500552575
# 1571  OCESN895830F0200252600
# 1572  OCESN895880F0500552634
# 1573  OCESN895940F0200252654
# 1574  OCESN895942F0900952655
#
#                                                  trajet  duree
# 0            Gare de Le Havre - Gare de Paris-St-Lazare    138
# 1              Gare de Dieppe - Gare de Paris-St-Lazare    145
# 2     Gare de Paris-St-Lazare - Gare de Rouen-Rive-D...     97
# 3           Gare de Cherbourg - Gare de Paris-St-Lazare    194
# 4                Gare de Caen - Gare de Paris-St-Lazare    149
# ...                                                 ...    ...
# 1570      Gare de Belfort-Ville - Gare de Lyon-Perrache    244
# 1571    Gare de Lons-le-Saunier - Gare de Lyon-Perrache    103
# 1572    Gare de Belfort-Ville - Gare de Lons-le-Saunier    144
# 1573  Gare de Besançon-Viotte - Gare de Lons-le-Saunier     89
# 1574         Gare de Bourg-en-Bresse - Gare de Mouchard     81
#
# [1575 rows x 3 columns]

# %% [markdown]
# ### **b. Routes:**

# %%
routes
# Out:
#                     route_id agency_id  route_short_name  \
# 0                 OCE1506035     OCESN               NaN
# 1                 OCE1506037     OCESN               NaN
# 2                 OCE1506036     OCESN               NaN
# 3                 OCE1209987     OCESN               NaN
# 4                 OCE1417992     OCESN               NaN
# ..                       ...       ...               ...
# 707  OCESN-87743005-87718833     OCESN               NaN
# 708  OCEZW-87576025-87576215     OCESN               NaN
# 709  OCEZW-87576025-87543165     OCESN               NaN
# 710  OCEZW-87543165-87576215     OCESN               NaN
# 711  OCESN-87471607-87471003     OCESN               NaN
#
#                         route_long_name  route_desc  route_type  route_url  \
# 0           Paris-Vernon-Rouen-Le Havre         NaN           2        NaN
# 1        Paris-Caen-Cherbourg/Trouville         NaN           2        NaN
# 2                       Paris-Granville         NaN           2        NaN
# 3               Paris-Bourges-Montluçon         NaN           2        NaN
# 4                        Paris - Nevers         NaN           2        NaN
# ..                                  ...         ...         ...        ...
# 707          Bourg-en-Bresse - Mouchard         NaN           2        NaN
# 708  Romorantin-Blanc-Argent - Valençay         NaN           2        NaN
# 709   Romorantin-Blanc-Argent - Salbris         NaN           2        NaN
# 710                  Salbris - Valençay         NaN           2        NaN
# 711                   Fougères - Rennes         NaN           7        NaN
#
#      route_color  route_text_color
# 0            NaN               NaN
# 1            NaN               NaN
# 2            NaN               NaN
# 3            NaN               NaN
# 4            NaN               NaN
# ..           ...               ...
# 707          NaN               NaN
# 708          NaN               NaN
# 709          NaN               NaN
# 710          NaN               NaN
# 711          NaN               NaN
#
# [712 rows x 9 columns]

# %% [markdown]
# ## **3. Normalization:**

# %% [markdown]
# ### **a. routes:**

# %%
routes.drop(columns=['route_short_name', 'route_desc', 'route_url', 'route_color', 'route_text_color'])
# Out:
#                     route_id agency_id                     route_long_name  \
# 0                 OCE1506035     OCESN         Paris-Vernon-Rouen-Le Havre
# 1                 OCE1506037     OCESN      Paris-Caen-Cherbourg/Trouville
# 2                 OCE1506036     OCESN                     Paris-Granville
# 3                 OCE1209987     OCESN             Paris-Bourges-Montluçon
# 4                 OCE1417992     OCESN                      Paris - Nevers
# ..                       ...       ...                                 ...
# 707  OCESN-87743005-87718833     OCESN          Bourg-en-Bresse - Mouchard
# 708  OCEZW-87576025-87576215     OCESN  Romorantin-Blanc-Argent - Valençay
# 709  OCEZW-87576025-87543165     OCESN   Romorantin-Blanc-Argent - Salbris
# 710  OCEZW-87543165-87576215     OCESN                  Salbris - Valençay
# 711  OCESN-87471607-87471003     OCESN                   Fougères - Rennes
#
#      route_type
# 0             2
# 1             2
# 2             2
# 3             2
# 4             2
# ..          ...
# 707           2
# 708           2
# 709           2
# 710           2
# 711           7
#
# [712 rows x 4 columns]

# %% [markdown]
# ## **4. Train Stations Structure:**

# %% [markdown]
# ### **a. Train Stations as Nodes:**

# %%
class TrainStation:
    def __init__(self, name):
        self.name = name
        self.next = None

# %% [markdown]
# ### **b. Routes as Linked List:**

# %%
class Route:
    def __init__(self, route):
        self.head = TrainStation(route[0])
        self.current = self.head
        for i in range (0, len(route)):
            current = TrainStation(route[i])
            if i != 0:
                self.current.next = current
                self.current = current
            
    def __repr__(self):
        node = self.head
        nodes = []
        while node is not None:
            nodes.append(node.name)
            node = node.next
        return " -> ".join(nodes)

# %%
def fetch_train_station_names(route):
    if " - " not in route:    
        return route.split("-")
    
    else:
        return route.split(" - ")

routes_list = [fetch_train_station_names(route) for route in routes['route_long_name']]
routes_list[:3]

# routes_list[0]
# routes_list[16]
# Out:
# [['Paris', 'Vernon', 'Rouen', 'Le Havre'],
#  ['Paris', 'Caen', 'Cherbourg/Trouville'],
#  ['Paris', 'Granville']]

# %%
route_0 = Route(routes_list[0])
route_0

routes_list[16]

linked_routes = []
for route in routes_list:
    linked_routes.append(Route(route))
linked_routes[:3]
# Out:
# [Paris -> Vernon -> Rouen -> Le Havre,
#  Paris -> Caen -> Cherbourg/Trouville,
#  Paris -> Granville]

# %% [markdown]
# ### **c. Alternative data type:**

# %%
routes_graph = {}

for route in routes_list:
    for i in range (0, len(route)):        
        if route[i] not in routes_graph:
            routes_graph.update({route[i]: []})
            if i != 0:
                routes_graph[route[i]].append(route[i - 1])
            if i != len(route) - 1:
                routes_graph[route[i]].append(route[i + 1])
        elif route[i - 1] not in routes_graph[route[i]] and i != 0:
            routes_graph[route[i]].append(route[i - 1])
        elif i < len(route) - 1 and route[i + 1] not in routes_graph[route[i]]:
            routes_graph[route[i]].append(route[i + 1])

print(routes_graph["Paris"])
print(routes_graph["Caen"])
print(routes_graph["Bourges"])
print(routes_graph)
# Out:
# ['Vernon', 'Caen', 'Granville', 'Bourges', 'Nevers', 'Orléans', 'Vaug. / Dreux / Argentan / Granville', 'Le Mans', 'CAR', 'Montargis']
# ['Paris', 'Cherbourg/Trouville', 'Le Mans', 'Tours']
# ['Paris', 'Montluçon', 'St Amand CAR', 'Issoudun', 'Tours', 'Orléans', 'Nevers']
# {'Paris': ['Vernon', 'Caen', 'Granville', 'Bourges', 'Nevers', 'Orléans', 'Vaug. / Dreux / Argentan / Granville', 'Le Mans', 'CAR', 'Montargis'], 'Vernon': ['Paris', 'Rouen'], 'Rouen': ['Vernon', 'Le Havre'], 'Le Havre': ['Rouen'], 'Caen': ['Paris', 'Cherbourg/Trouville', 'Le Mans', 'Tours'], 'Cherbourg/Trouville': ['Caen'], 'Granville': ['Paris'], 'Bourges': ['Paris', 'Montluçon', 'St Amand CAR', 'Issoudun', 'Tours', 'Orléans', 'Nevers'], 'Montluçon': ['Bourges', 'Guéret', 'Gueret', 'Bordeaux'], 'Nevers': ['Paris', 'Dijon', 'Decize', 'Luzy', 'Moulins', 'Paray', 'Tours', 'Orléans', 'Bourges', 'Vierzon', 'Dijon-Ville', 'Autun'], 'Orléans': ['Paris', 'Tours', 'Nevers', 'Bourges'], 'Tours': ['Orléans', 'Paray', 'Chinon CAR', 'Chateau du Loir CAR', 'Loches CAR', 'Chateauroux CAR', 'Vendôme', 'Nevers', 'Saumur', 'Angers', ' Chateau Du Loir', 'Alençon', 'Caen', 'Nantes', 'Bourges', 'Vierzon'], '[IC351] PARIS': ['AMIENS'], 'AMIENS': ['[IC351] PARIS', 'BOULOGNE', '[IC356] PARIS'], 'BOULOGNE': ['AMIENS', 'CALAIS'], 'CALAIS': ['BOULOGNE'], '[IC372] PARIS': ['MAUBEUGE'], 'MAUBEUGE': ['[IC372] PARIS', 'CAMBRAI'], 'CAMBRAI': ['MAUBEUGE'], 'Vaug. / Dreux / Argentan / Granville': ['Paris'], 'Le Mans / Alençon / Argentan  / Caen': [], 'Le Mans': ['Paris', 'Angers', 'Nogent', 'Laval', 'Chateau du Loir', 'Caen', 'Le Croisic', 'Rennes'], 'ORL': ['TOURS', 'PAZ'], 'TOURS': ['ORL', 'ST PIERRE ""NAVETTES TGV""""', 'POITIERS', 'SAUMUR'], 'Paray': ['Tours', 'Lyon', 'Nevers', 'Montchanin'], 'Lyon': ['Paray', 'Grenoble', 'Marseille Multi Activités', '(LTP)', '(LTP', 'Cars Roanne', 'Cars Mâcon', 'Cars Villefranche', 'Genève', 'Bellegarde', 'Belfort', 'Clermont-Fd', '(Macon)', 'Roanne', 'St-Etienne', 'Villefranche', 'St-André-le-Gaz', 'Bourg-en-Bresse (via Villars)', 'Le Puy'], 'Villefranche': ['La Tour de Carol', 'Perpignan', 'Lyon'], 'La Tour de Carol': ['Villefranche'], 'ROMANS/BRIANCON': [], 'IC MARSEILLE/SISTERON/BRIANCON + GAP/BRI': [], 'Aix-en-Provence': ['Marseille-St-Charles'], 'Marseille-St-Charles': ['Aix-en-Provence', 'Gap', 'Briançon', 'Avignon-TGV', 'Avignon-Centre'], 'Gap': ['Marseille-St-Charles', 'Cars Grenoble', 'Grenoble'], 'Briançon': ['Marseille-St-Charles', 'Gap'], 'IV Marseille': ['Nice'], 'Nice': ['IV Marseille', 'Menton'], 'Menton': ['Nice', 'Vintimille'], 'Vintimille': ['Menton', 'Les Arcs'], 'Geneve': ['Evian'], 'Evian': ['Geneve', 'Annecy', 'Annemasse', 'Bellegarde'], 'Annecy': ['Evian', 'Valence', 'Grenoble', 'Cars Lyon', 'Aix-Les-Bains', 'Cars Chambéry', 'Cars TER Bellegarde', 'La Roche-sur-Foron', 'Annemasse', 'Chambéry', 'St Gervais'], 'Valence': ['Annecy', 'Avignon', 'Cars Grenoble', 'St Marcellin', 'Macon'], 'Avignon': ['Valence', 'Port Bou'], 'Chambéry-Chal.-les-Eaux': ['Valence-Ville', 'Grenoble', 'St-André-le-Gaz', 'Rives'], 'Valence-Ville': ['Chambéry-Chal.-les-Eaux', 'Grenoble U.-Gières'], 'Grenoble': ['Annecy', 'Lyon', 'Cars Lyon', 'Cars Modane', 'Cars Bourg-St-Maurice', 'Genève', 'Chambéry-Chal.-les-Eaux', 'Gap', 'Veynes', 'St-André-le-Gaz'], 'Marseille Multi Activités': ['Lyon'], 'Paris Bercy': ['Dijon', 'Auxerre'], 'Dijon': ['Paris Bercy', 'Lyon (Multi-Activités)', 'Nevers via Moulins', 'Nevers', 'Is-sur-Tille', 'Bourg en Bresse (Multi-Activités)', 'Besançon', 'Autun', 'Culmont', 'Laroche', 'Chalon'], 'Lyon (Multi-Activités)': ['Dijon', 'Paray'], '(LTP)': ['Lyon', 'Chambéry'], 'Chambéry': ['(LTP)', 'Bourg-St-Maurice', 'AMB)', 'Cars Bourg-en-Bresse', 'Cars Ambérieu', 'Modane', 'Ambérieu', 'Grenoble Gières', 'Annecy', 'St Marcellin'], 'Bourg-St-Maurice': ['Chambéry'], '(LTP': ['Lyon', 'AMB)', 'Cars Lyon'], 'AMB)': ['(LTP', 'Chambéry'], 'Besançon': ['Morteau', 'Le Locle', ' Mouchard', 'Dijon', 'Belfort'], 'Morteau': ['Besançon', 'La Chaux de Fonds'], 'La Chaux de Fonds': ['Morteau'], 'Pontarlier': ['Frasne'], 'Frasne': ['Pontarlier', 'Vallorbe', ' Vallorbe'], 'Vallorbe': ['Frasne'], 'Dole / Pontarlier': ['Besançon / Dole / St Claude'], 'Besançon / Dole / St Claude': ['Dole / Pontarlier'], 'Belfort': ['Delle', 'Cars  ...

# %%
len(routes_graph)
# Out:
# 814

# %% [markdown]
# ### **d. Get all cities coordinates:**

# %%
cities_coordinates = []
for city in routes_graph:
#     print(city)
#     print(requests.get("https://api-adresse.data.gouv.fr/search/?q={}&type=street".format(city.lower())))
    ret = requests.get("https://api-adresse.data.gouv.fr/search/?q={}&type=municipality".format(city.lower())).json()
#     print(ret)
    if len(ret["features"]) >= 1:
#         print(ret["features"][0]["geometry"]["coordinates"])
        cities_coordinates.append({city: ret["features"][0]["geometry"]["coordinates"]})
cities_coordinates
# Out:
# [{'Paris': [2.347, 48.859]},
#  {'St-André-le-Gaz': [5.530744, 45.548607]},
#  {'(Pierrelatte)': [4.693067, 44.361268]},
#  {'(Macon)': [4.79195, 46.30453]},
#  {'Firminy': [4.287652, 45.386905]},
#  {'Lyon-Perrache': [4.835, 45.758]},
#  {'St-Etienne-Châteaucreux': [3.104092, 43.662753]},
#  {'Givors-Ville': [4.756036, 45.582848]},
#  {'Bourg': [-0.553991, 45.044256]},
#  {'Lyon Perrache': [4.835, 45.758]},
#  {'Roanne': [4.073807, 46.043448]},
#  {'Ambérieu-en-Bugey': [5.36516, 45.959083]},
#  {'Romans Valence Die': [4.923011, 44.921313]},
#  {'Le Puy': [0.065524, 44.661979]},
#  {'Lyon St-Paul': [4.835, 45.758]},
#  {'Brignais': [4.755425, 45.674741]},
#  {'Laroche': [3.470323, 47.967602]},
#  {'Chalon': [4.931454, 45.447447]},
#  {'Mâcon': [4.810857, 46.322863]},
#  {'Le Creusot': [4.426794, 46.806421]},
#  {'Besançon-Franche-Comté': [5.99411, 47.2564]},
#  {'Besançon-Viotte': [5.99411, 47.2564]},
#  {'Mouchard': [5.791835, 46.976744]},
#  {'Lons-le-Saunier': [5.559193, 46.677084]},
#  {'Belfort-Ville': [6.991726, 47.45598]},
#  {'Fougères': [-1.194205, 48.356055]}]

# %%
len(cities_coordinates)
# Out:
# 679

# %%
len(routes_graph) - len(cities_coordinates)
# Out:
# 135

# %% [markdown]
# ## **5. Ponderations:**

# %% [markdown]
# ### **a. Angle *based* Ponderation:**

# %%
import math

def angle_calculation(a, b, c):
    ang = math.degrees(math.atan2(c[1]-b[1], c[0]-b[0]) - math.atan2(a[1]-b[1], a[0]-b[0]))
    ang = ang + 360 if ang < 0 else ang
    return ang if ang < 180 else ang - 180

angle_calculation(cities_coordinates[10]["Orléans"], cities_coordinates[0]["Paris"], cities_coordinates[2]["Rouen"])
# Out:
# 88.98753395838276

# %% [markdown]
# ### **b. Distance *based* Ponderation:**

# %%
from math import radians, cos, sin, asin, sqrt

def haversine(city, node):
    lon1, lat1, lon2, lat2 = map(radians, [city[0], city[1], node[0], node[1]])

    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371
    return c * r

haversine(cities_coordinates[10]["Orléans"], cities_coordinates[0]["Paris"])
# Out:
# 114.19546233279856

# %% [markdown]
# ### **c. Normalize Values:**

# %%
ponderation_factor_angle = 1
ponderation_factor_dist = 1

def normalize_angle(angle):
    return angle * 2 / 180 * ponderation_factor_angle

def normalize_dist(dist_node, dist):
    if dist == 0:
        return 0
    return dist_node * 2 / dist / 2 * ponderation_factor_dist

print(normalize_angle(30))
print(normalize_angle(180))

print(normalize_dist(110, 300))
print(normalize_dist(0, 300))
print(normalize_dist(300, 300))
print(normalize_dist(600, 300))
# Out:
# 0.3333333333333333
# 2.0
# 0.36666666666666664
# 0.0
# 1.0
# 2.0

# %% [markdown]
# ### **d. Generate Ponderations:**

# %%
cities_coordinates[:3]
# Out:
# [{'Paris': [2.347, 48.859]},
#  {'Vernon': [1.494472, 49.089623]},
#  {'Rouen': [1.093912, 49.440286]}]

# %% [markdown]
# Get this `list` of `dict` converted to `dict` with the *attribute name* as *key*.

# %%
# cities_ponderates = {city: normalize_angle(angle_calculation()) + normalize_dist(haversine(dist_node, dist)) for city}

cities_normalized = {}
for city in cities_coordinates:
    city_name = list(city.keys())[0]
    cities_normalized.update({city_name: city[city_name]})
print(list(cities_normalized.items())[:5])
# Out:
# [('Paris', [2.347, 48.859]), ('Vernon', [1.494472, 49.089623]), ('Rouen', [1.093912, 49.440286]), ('Le Havre', [0.129995, 49.507345]), ('Caen', [-0.372291, 49.184571])]

# %% [markdown]
# All cities:

# %%
cities_ponderate = {}
dest = "Rouen"
for city in cities_coordinates:
#     print("=======================================================")
#     print("city:")
#     print(city)
    city_name = list(city.keys())[0]
    for node in routes_graph[city_name]:
#         print(cities_normalized[node][0])
#         print(city)
        if node in cities_normalized and dest in cities_normalized and city_name in city:
            dist_pond = normalize_dist(haversine(cities_normalized[node], cities_normalized[dest]), haversine(city[city_name], cities_normalized[dest]))
            angle_pond = normalize_angle(angle_calculation(cities_normalized[node], city[city_name] ,cities_normalized[dest]))
#             print(node)
#             print(dist_pond)
#             print(angle_pond)
            cities_ponderate.update({node: dist_pond+angle_pond})
# #     print("=======================================================")

print(dict(list(cities_ponderate.items())[:15]))
# Out:
# {'Vernon': 0.4577770830624282, 'Caen': 1.9959846362329743, 'Granville': 3.5588346468030636, 'Bourges': 1.981856547744782, 'Nevers': 2.619631528199404, 'Orléans': 1.4424579092098364, 'Le Mans': 0.6654904677506301, 'CAR': 4.299795387634834, 'Montargis': 1.5120128346769017, 'Paris': 0.8289890483283516, 'Rouen': 0.0, 'Le Havre': 0.0442179267955996, 'Cherbourg/Trouville': 2.217918954323537, 'Tours': 2.8777584643572345, 'Montluçon': 1.987192477244143}

# %% [markdown]
# Specific city:

# %%
cities_ponderate = {}
base = "Paris"
dest = "Rouen"
city_name = base

# def ponderation(base, dest, currrent_node):
for node in routes_graph[city_name]:
#     print(cities_normalized[city_name])
#     print(node)
    if node in cities_normalized and dest in cities_normalized:
#         print(node)
        dist_pond = normalize_dist(haversine(cities_normalized[node], cities_normalized[dest]), haversine(cities_normalized[city_name], cities_normalized[dest]))
        angle_pond = normalize_angle(angle_calculation(cities_normalized[node], cities_normalized[city_name] ,cities_normalized[dest]))
#         print(node)
#         print(dist_pond)
#         print(angle_pond)
        cities_ponderate.update({node: dist_pond+angle_pond})
#     print("=======================================================")

print(dict(list(cities_ponderate.items())[:15]))
# Out:
# {'Vernon': 2.3269546423245724, 'Caen': 2.7840794556952093, 'Granville': 3.5588346468030636, 'Bourges': 3.2057134399770377, 'Nevers': 3.2604504645341863, 'Orléans': 2.637720941567005, 'Le Mans': 3.0376870556388376, 'CAR': 6.986372955308585, 'Montargis': 2.2489567887295108}

# %% [markdown]
# ### **e. Recursive function:**

# %%
def recursive_graph_exploration(node, dest, current_route, valide_route):
    if node == dest:
        valide_route.append(current_route)
    if node in current_route:
        current_route = []
    else:
        current_route.append(node)
        for junction in routes_grpah[node]:
            return recursive_graph_exploration(junction, dest, current_route, valide_route)
